# %%
import pandas as pd
df = pd.read_csv('berkshire_holdings_combined.csv')
df
# Out:
#          cusip               nameOfIssuer titleOfClass periodOfReport  \
# 0    00287Y109                 ABBVIE INC          COM     2020-09-30
# 1    00287Y109                 ABBVIE INC          COM     2020-12-31
# 2    00287Y109                 ABBVIE INC          COM     2021-03-31
# 3    00287Y109                 ABBVIE INC          COM     2021-06-30
# 4    00287Y109                 ABBVIE INC          COM     2021-09-30
# ..         ...                        ...          ...            ...
# 779  G9001E128  LIBERTY LATIN AMERICA LTD     COM CL C     2023-12-31
# 780  G9001E128  LIBERTY LATIN AMERICA LTD     COM CL C     2024-03-31
# 781  H1467J104              CHUBB LIMITED          COM     2023-09-30
# 782  H1467J104              CHUBB LIMITED          COM     2023-12-31
# 783  H1467J104              CHUBB LIMITED          COM     2024-03-31
#
#           value  shrs_or_prn_amt
# 0       1862541         21264316
# 1       2735870         25533082
# ...
